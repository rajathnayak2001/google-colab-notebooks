# %% [markdown]
# <a href="https://colab.research.google.com/github/rajathnayak2001/google-colab-notebooks/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader

# %%
downloader.download("walls and floors",200,output_dir='images')
# Out:
# [%] Downloading Images to /content/images/walls and floors
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 150 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/ff/a0/8e/ffa08e49fa8b5cc4e6026569be69ad25.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/736x/11/c7/09/11c7092ce178e58a2a37361e0ac822d0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/c5/08/a8/c508a879cf3b74dbcbd684f1157f6f78.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/40/1a/27/401a2787578ddf596e3405e672c4c0a7.png
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/originals/eb/e6/dc/ebe6dc89363aa5bb4dcdb4ae7284dd1a.png
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.tileshop.com/blog/wp-content/uploads/2019/08/Effect_Plymouth_Hero-768x896.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r /content/file.zip /content/Folder_To_Zip
# Out:
# 	zip warning: name not matched: /content/Folder_To_Zip
#
# zip error: Nothing to do! (try: zip -r /content/file.zip . -i /content/Folder_To_Zip)

# %%
from google.colab import files
files.download("/content/images/walls_and_floors")
